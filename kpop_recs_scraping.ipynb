# %% [markdown]
# # Spotify Scraping Project

# %% [markdown]
# ## Setup Code

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import pandas as pd
import numpy as np
import time 
import re

# %%
client_id = ''
client_secret = ''

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
input_data = pd.read_csv("273_kArtists.csv")

# %% [markdown]
# ## Retrieving IDs for 'album', single', 'appears_on', 'compilation'

# %% [markdown]
# ### Retrieving Album Names and Album IDs from Artists

# %%
all_artist_names = []
all_artist_ids = []
all_album_names = []
all_album_uris = []

# Retrieve Album ID using the Album Names
for index in input_data.index:
    artist_name = input_data["Artist"][index]
    artist_id = input_data["Spotify_Id"][index]

    try:
        spotify_artist_id = "spotify:artist:" + str(artist_id)
        results = sp.artist_albums(spotify_artist_id, album_type='album', country='US')
        albums = results['items']

        while results['next']:
            results = sp.next(results)
            albums.extend(results['items'])

        # unique_album_names = set()
        for album in albums:
            all_artist_names.append(artist_name)
            all_artist_ids.append(artist_id)
            all_album_names.append(album['name'])
            all_album_uris.append(album['uri'])

    except:
        print("error with finding " + artist_name)

# %%
# Adding resulting artist name, artist id, album name, album id to a new dataframe
temp_data = {'Artist': all_artist_names,
            'Artist_Id': all_artist_ids,
            'Album_Name': all_album_names,
            'Album_Id': all_album_uris}

artist_id_album_id = pd.DataFrame(temp_data)

# %%
artist_id_album_id.head(10)
# Out:
#       Artist               Artist_Id  \
# 0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 1     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 2     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 3     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 4     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 5     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 6     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 7     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 8  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 9  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
#
#                                           Album_Name  \
# 0                          FOREVER 2001 LIVE CONCERT
# 1                            99 LIVE IN SEOUL (Live)
# 2                      Outside Castle -The 5th Album
# 3  Age Of Peace (Original Motion Picture Soundtrack)
# 4                             I Yah! - The 4th Album
# 5                       Resurrection - The 3rd Album
# 6                                     Wolf And Sheep
# 7   We Hate All Kinds of Violence... - The 1st Album
# 8                                      ANOTHER LIGHT
# 9                               THE 20TH ANNIVERSARY
#
#                                Album_Id
# 0  spotify:album:697cPaD568S5Zt4bgo4cQf
# 1  spotify:album:64IbiOh32NqTuHxy5wsiBG
# 2  spotify:album:0qqE8lGVSRDqePeWpKy1Fg
# 3  spotify:album:73PXsDhLv6RV01AyVN8Ymx
# 4  spotify:album:2hTRBrQt64fYVfZl9viZh3
# 5  spotify:album:0yJ02boB03UsjObzoXJ5O4
# 6  spotify:album:2RWrsv0kIKreXvm7IrMeYN
# 7  spotify:album:23Xh3YpgzRuJ2DAW5X7MsP
# 8  spotify:album:5f2LzIFxljQF4FH7w3rXcQ
# 9  spotify:album:7AKNe7vxI0Z6CCyy7zaZ26

# %%
artist_id_album_id.to_csv("artist_id_album_id.csv")

# %% [markdown]
# ### Retrieving Single and Single IDs from Artists

# %%
all_artist_names = []
all_artist_ids = []
all_single_names = []
all_single_uris = []

# Retrieve Single "Album" ID using the Album Names

for index in input_data.index:
    artist_name = input_data["Artist"][index]
    artist_id = input_data["Spotify_Id"][index]

    try:
        spotify_artist_id = "spotify:artist:" + str(artist_id)
        results = sp.artist_albums(spotify_artist_id, album_type='single', country='US')
        singles = results['items']

        while results['next']:
            results = sp.next(results)
            singles.extend(results['items'])

        for single in singles:
            all_artist_names.append(artist_name)
            all_artist_ids.append(artist_id)
            all_single_names.append(single['name'])
            all_single_uris.append(single['uri'])

    except:
        print("error with finding " + artist_name)

# %%
temp_data = {'Artist': all_artist_names,
            'Artist_Id': all_artist_ids,
            'Single_Album_Name': all_single_names,
            'Single_Album_Id': all_single_uris}

artist_id_single_album_id = pd.DataFrame(temp_data)

# %%
artist_id_single_album_id.head(10)
# Out:
#       Artist               Artist_Id  \
# 0  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 3     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 4     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 5    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 6    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 7    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0
# 8    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0
# 9    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0
#
#                               Single_Album_Name  \
# 0                               DON'T LOOK BACK
# 1                                   ALL FOR YOU
# 2                                   THREE WORDS
# 3                     Love (story) - SM STATION
# 4                                       Remixed
# 5        FIN.K.L SINGLE "Like the song remains"
# 6                         Fin.K.L Digital Album
# 7          SHINHWA TWENTY SPECIAL ALBUM 'HEART'
# 8  SHINHWA TWENTY GIFT SINGLE ‘All Your Dreams’
# 9                              UNCHANGING PT. 1
#
#                         Single_Album_Id
# 0  spotify:album:63fxv7o113Zji3oLeXgswm
# 1  spotify:album:7vqIRL00YfTtuO0sSAK3Uv
# 2  spotify:album:6pN2wvuzGHURmVNXbpRaei
# 3  spotify:album:3j2XirA7CqIqkwuQfO7wkR
# 4  spotify:album:4jBlaJL3oauZCX9VeseBJC
# 5  spotify:album:1Qwyg4hhC6gv8x42kq9Qru
# 6  spotify:album:08u61FSaRTXKe6CD7RePvp
# 7  spotify:album:1F4ew4S5UvxCTg28U2J1cR
# 8  spotify:album:2txBzMBsQDnw0kT6rFpQRB
# 9  spotify:album:5TrZNDuG4byRTlcMsX6OaS

# %%
artist_id_single_album_id.to_csv("artist_id_single_album_id.csv")

# %% [markdown]
# ### Retrieving 'Appears On' and 'Appears On' ID from Artist ID

# %%
all_artist_names = []
all_artist_ids = []
all_appears_on_names = []
all_appears_on_uris = []

# Retrieve Album ID using the Album Names

for index in input_data.index:
    artist_name = input_data["Artist"][index]
    artist_id = input_data["Spotify_Id"][index]

    try:
        spotify_artist_id = "spotify:artist:" + str(artist_id)
        results = sp.artist_albums(spotify_artist_id, album_type='appears_on', country='US')
        appears_on = results['items']

        while results['next']:
            results = sp.next(results)
            appears_on.extend(results['items'])

        for appearance in appears_on:
            all_artist_names.append(artist_name)
            all_artist_ids.append(artist_id)
            all_appears_on_names.append(appearance['name'])
            all_appears_on_uris.append(appearance['uri'])
    
    except:
        print("error with finding " + artist_name)

# %%
temp_data = {'Artist': all_artist_names,
            'Artist_Id': all_artist_ids,
            'Appears_On_Name': all_appears_on_names,
            'Appears_On_Id': all_appears_on_uris}

artist_id_appears_on_id = pd.DataFrame(temp_data)

# %%
artist_id_appears_on_id.head(10)
# Out:
#       Artist               Artist_Id  \
# 0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 1     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 3     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 4     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 5     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 6     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 7     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 8    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 9    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
#
#                               Appears_On_Name  \
# 0               Winter Vacation in SMTOWN.com
# 1                     Christmas in SMTOWN.com
# 2     90's trendy K-pop music Best 20 Vol. 15
# 3              Superhero (My Knight) Remix EP
# 4          2002 SUMMER VACATION in SMTOWN.COM
# 5  Winter Vacation in SMTOWN.com - Angel Eyes
# 6               Winter Vacation in SMTOWN.com
# 7                     Christmas in SMTOWN.com
# 8                                        韓劇情緣
# 9               All About Eve (MBC DRAMA) OST
#
#                           Appears_On_Id
# 0  spotify:album:5aBuzpJ2UNoPwQhee47UQk
# 1  spotify:album:7ccOMxO0n9DjSfLBHhWMDT
# 2  spotify:album:2lW9DhcA1StfL54mw5pgC2
# 3  spotify:album:5v6Jrf7O7k99sPkMTU2Noo
# 4  spotify:album:59KnIxsURaQ1wabZZpyf67
# 5  spotify:album:3nHNulZ1pybkNcM5NeErQA
# 6  spotify:album:5aBuzpJ2UNoPwQhee47UQk
# 7  spotify:album:7ccOMxO0n9DjSfLBHhWMDT
# 8  spotify:album:2SgMnH1w8G47RWCAt18wwY
# 9  spotify:album:7LDnsb1ATqmSM3NYqefvfL

# %%
artist_id_appears_on_id.to_csv("artist_id_appears_on_id.csv")

# %% [markdown]
# ### Retrieving Compilation and Compilation ID from Artist ID

# %%
all_artist_names = []
all_artist_ids = []
all_compilation_names = []
all_compilation_uris = []

# Retrieve Album ID using the Album Names

for index in input_data.index:
    artist_name = input_data["Artist"][index]
    artist_id = input_data["Spotify_Id"][index]

    try:
        spotify_artist_id = "spotify:artist:" + str(artist_id)
        results = sp.artist_albums(spotify_artist_id, album_type='compilation', country='US')
        compilations = results['items']

        while results['next']:
            results = sp.next(results)
            compilations.extend(results['items'])

        for compiled in compilations:
            all_artist_names.append(artist_name)
            all_artist_ids.append(artist_id)
            all_compilation_names.append(compiled['name'])
            all_compilation_uris.append(compiled['uri'])

    except:
        print("error with finding " + artist_name)

# %%
temp_data = {'Artist': all_artist_names,
            'Artist_Id': all_artist_ids,
            'Compilation_Name': all_compilation_names,
            'Compilation_Id': all_compilation_uris}

artist_id_compilation_id = pd.DataFrame(temp_data)

# %%
artist_id_compilation_id.head(10)
# Out:
#        Artist               Artist_Id  \
# 0     Click-B  2kOGSFThgEzPEjL4fFB25w
# 1         BoA  4muJrGMndyYWqZtfk8OWy4
# 2     BIGBANG  4Kxlr1PRlDKEB0ekOCyHgX
# 3         2PM  5iRPbkcPmqAFFwDUj6ywVS
# 4         BTS  3Nrfpe0tUJi4K4DXYWgMUX
# 5  Stray Kids  2dIgFjalVxs4ThymZ67YCE
# 6     4Minute  6cdC1cwqh3eJAXaxXJt2jv
# 7    G-Dragon  30b9WulBM8sFuBo17nNq9c
# 8     TAEYANG  6udveWUgX4vu75FF0DTrXV
# 9        BIBI  6UbmqUEgjLA6jAcXwbM1Z9
#
#                                Compilation_Name  \
# 0                           The Best Of Click-B
# 1                                  BEST OF SOUL
# 2                 THE BEST OF BIGBANG 2006-2014
# 3            THE BEST OF 2PM in Japan 2011-2016
# 4                                 BTS, THE BEST
# 5                                       SKZ2020
# 6                               Best of 4Minute
# 7  COUP D'ETAT [+ ONE OF A KIND & HEARTBREAKER]
# 8                          RISE [+ SOLAR & HOT]
# 9                                       Gringas
#
#                          Compilation_Id
# 0  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO
# 1  spotify:album:0gxS6h33HGI5jEAgcMsTWA
# 2  spotify:album:1JwbdXLKJVffgSW95WcTUp
# 3  spotify:album:5rEgHD2JSK9RRxyKtXsImD
# 4  spotify:album:6bN241dPMC54Ac6zV1B8hl
# 5  spotify:album:4hk05fFLNquJc8w5htXZDi
# 6  spotify:album:502uBQOdyp6A3En53ZJFCo
# 7  spotify:album:1mVPbaMZGsPh5gzhvO6BBX
# 8  spotify:album:2Z80u1PO03Jk4eUccBUR90
# 9  spotify:album:37IFkjRyzSbBWubkkHD6RL

# %%
artist_id_compilation_id.to_csv("artist_id_compilation_id.csv")

# %% [markdown]
# ## Locating Tracks and Attaching to Albums, Singles, Appears On, and Compilation

# %% [markdown]
# ### Locating and Attaching for Albums

# %%
artist_album_data = pd.read_csv("artist_id_album_id.csv", index_col=[0])

# %%
artist_album_data.head(10)
# Out:
#       Artist               Artist_Id  \
# 0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 1     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 2     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 3     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 4     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 5     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 6     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 7     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 8  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 9  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
#
#                                           Album_Name  \
# 0                          FOREVER 2001 LIVE CONCERT
# 1                            99 LIVE IN SEOUL (Live)
# 2                      Outside Castle -The 5th Album
# 3  Age Of Peace (Original Motion Picture Soundtrack)
# 4                             I Yah! - The 4th Album
# 5                       Resurrection - The 3rd Album
# 6                                     Wolf And Sheep
# 7   We Hate All Kinds of Violence... - The 1st Album
# 8                                      ANOTHER LIGHT
# 9                               THE 20TH ANNIVERSARY
#
#                                Album_Id
# 0  spotify:album:697cPaD568S5Zt4bgo4cQf
# 1  spotify:album:64IbiOh32NqTuHxy5wsiBG
# 2  spotify:album:0qqE8lGVSRDqePeWpKy1Fg
# 3  spotify:album:73PXsDhLv6RV01AyVN8Ymx
# 4  spotify:album:2hTRBrQt64fYVfZl9viZh3
# 5  spotify:album:0yJ02boB03UsjObzoXJ5O4
# 6  spotify:album:2RWrsv0kIKreXvm7IrMeYN
# 7  spotify:album:23Xh3YpgzRuJ2DAW5X7MsP
# 8  spotify:album:5f2LzIFxljQF4FH7w3rXcQ
# 9  spotify:album:7AKNe7vxI0Z6CCyy7zaZ26

# %%
list_of_track_df = []

for ind in artist_album_data.index:
    album_id = artist_album_data["Album_Id"][ind]
    tracks = sp.album_tracks(album_id = album_id)
    
    try:
        for track in tracks['items']:
            # Retrieve each track's Spotify qualities
            track_name = track['name']
            track_uri = track['uri']
            track_features = sp.audio_features(track_uri)
            track_features_df = pd.DataFrame(track_features)
            track_features_df['Track_Title'] = track_name

            # Combine track and artist information with the features dataframe
            temp_df = pd.concat([artist_album_data.loc[ind:ind], 
                                track_features_df.set_index(artist_album_data.loc[ind:ind].index)], axis = 1)
            list_of_track_df.append(temp_df)

    except:
        print("Ran into an error - rerun please!")
        print(album_id)

# %%
temp_df = pd.concat(list_of_track_df, ignore_index=True)

# %%
temp_df.head(10)
# Out:
#    Artist               Artist_Id                 Album_Name  \
# 0  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 1  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 2  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 3  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 4  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 5  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 6  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 7  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 8  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 9  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
#
#                                Album_Id  danceability  energy   key  loudness  \
# 0  spotify:album:697cPaD568S5Zt4bgo4cQf         0.209   0.963   6.0   -12.900
# 1  spotify:album:697cPaD568S5Zt4bgo4cQf         0.397   0.901   4.0    -6.970
# 2  spotify:album:697cPaD568S5Zt4bgo4cQf         0.542   0.913   1.0    -7.763
# 3  spotify:album:697cPaD568S5Zt4bgo4cQf         0.436   0.666  10.0   -14.143
# 4  spotify:album:697cPaD568S5Zt4bgo4cQf         0.366   0.778   7.0    -9.239
# 5  spotify:album:697cPaD568S5Zt4bgo4cQf         0.667   0.914   1.0    -8.073
# 6  spotify:album:697cPaD568S5Zt4bgo4cQf         0.702   0.768  10.0    -8.454
# 7  spotify:album:697cPaD568S5Zt4bgo4cQf         0.464   0.918   1.0    -7.740
# 8  spotify:album:697cPaD568S5Zt4bgo4cQf         0.380   0.524   3.0    -9.068
# 9  spotify:album:697cPaD568S5Zt4bgo4cQf         0.463   0.421   0.0    -8.005
#
#    mode  speechiness  ...    tempo            type                      id  \
# 0   0.0       0.1330  ...  131.864  audio_features  6KOn7RweqUBSZWoKKkHFRb
# 1   1.0       0.2850  ...  171.944  audio_features  1khANf67sdS8kUkjmF218J
# 2   1.0       0.2410  ...   97.051  audio_features  4XkT2bHdbHMPukCpj7mXPJ
# 3   0.0       0.6320  ...  107.013  audio_features  65a4TY00ChiawzHVH4xcDO
# 4   0.0       0.0714  ...   99.995  audio_features  3vYZaL9lMZ1uKURbcEq4Jz
# 5   1.0       0.0873  ...  110.037  audio_features  7H9Y6xJsNQLaPLw3COdgo5
# 6   0.0       0.1770  ...   96.979  audio_features  4xnlCh34wSnw2JbRRYWqBH
# 7   0.0       0.0738  ...  177.882  audio_features  2lyftOm9r45ja4MC7nXWXc
# 8   1.0       0.0388  ...   76.602  audio_features  0r3yOoI5592LzWuBGIntBH
# 9   1.0       0.0247  ...   86.608  audio_features  7hvqkt1HOjO1VQiTsBQsPz
#
#                                     uri  \
# 0  spotify:track:6KOn7RweqUBSZWoKKkHFRb
# 1  spotify:track:1khANf67sdS8kUkjmF218J
# 2  spotify:track:4XkT2bHdbHMPukCpj7mXPJ
# 3  spotify:track:65a4TY00ChiawzHVH4xcDO
# 4  spotify:track:3vYZaL9lMZ1uKURbcEq4Jz
# 5  spotify:track:7H9Y6xJsNQLaPLw3COdgo5
# 6  spotify:track:4xnlCh34wSnw2JbRRYWqBH
# 7  spotify:track:2lyftOm9r45ja4MC7nXWXc
# 8  spotify:track:0r3yOoI5592LzWuBGIntBH
# 9  spotify:track:7hvqkt1HOjO1VQiTsBQsPz
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6KOn7RweqUBS...
# 1  https://api.spotify.com/v1/tracks/1khANf67sdS8...
# 2  https://api.spotify.com/v1/tracks/4XkT2bHdbHMP...
# 3  https://api.spotify.com/v1/tracks/65a4TY00Chia...
# 4  https://api.spotify.com/v1/tracks/3vYZaL9lMZ1u...
# 5  https://api.spotify.com/v1/tracks/7H9Y6xJsNQLa...
# 6  https://api.spotify.com/v1/tracks/4xnlCh34wSnw...
# 7  https://api.spotify.com/v1/tracks/2lyftOm9r45j...
# 8  https://api.spotify.com/v1/tracks/0r3yOoI5592L...
# 9  https://api.spotify.com/v1/tracks/7hvqkt1HOjO1...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6KOn...     90333.0
# 1  https://api.spotify.com/v1/audio-analysis/1khA...    278333.0
# 2  https://api.spotify.com/v1/audio-analysis/4XkT...    320533.0
# 3  https://api.spotify.com/v1/audio-analysis/65a4...    284427.0
# 4  https://api.spotify.com/v1/audio-analysis/3vYZ...    278667.0
# 5  https://api.spotify.com/v1/audio-analysis/7H9Y...    227067.0
# 6  https://api.spotify.com/v1/audio-analysis/4xnl...    266173.0
# 7  https://api.spotify.com/v1/audio-analysis/2lyf...    244160.0
# 8  https://api.spotify.com/v1/audio-analysis/0r3y...    167507.0
# 9  https://api.spotify.com/v1/audio-analysis/7hvq...    270333.0
#
#   time_signature                                        Track_Title    0
# 0            4.0                                     Opening - Live  NaN
# 1            4.0                                      I yah! - Live  NaN
# 2            4.0           Git It Up! / 전사의 후예 / You Got Gun - Live  NaN
# 3            5.0                                Opening Ment - Live  NaN
# 4            4.0  It's Been Raining Since You Left Me / Delight ...  NaN
# 5            4.0                 N.B.K.(Natural Born Killer) - Live  NaN
# 6            4.0                              Time Will Tell - Live  NaN
# 7            4.0          Livin' La Vida Loca (Tony Special) - Live  NaN
# 8            4.0                      Only You (KANGTA Solo) - Live  NaN
# 9            4.0            Right Here Waiting (KANGTA Solo) - Live  NaN
#
# [10 rows x 24 columns]

# %%
temp_df.to_csv("v1_album_to_song.csv")

# %% [markdown]
# ### Locating and Attaching "Singles" and "Single Tracks"

# %%
singles_input_data = pd.read_csv("artist_id_single_album_id.csv")

# %%
singles_input_data.head(10)
# Out:
#    Unnamed: 0     Artist               Artist_Id  \
# 0           0  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 1           1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 2           2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 3           3     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 4           4     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 5           5    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 6           6    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 7           7    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0
# 8           8    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0
# 9           9    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0
#
#                               Single_Album_Name  \
# 0                               DON'T LOOK BACK
# 1                                   ALL FOR YOU
# 2                                   THREE WORDS
# 3                     Love (story) - SM STATION
# 4                                       Remixed
# 5        FIN.K.L SINGLE "Like the song remains"
# 6                         Fin.K.L Digital Album
# 7          SHINHWA TWENTY SPECIAL ALBUM 'HEART'
# 8  SHINHWA TWENTY GIFT SINGLE ‘All Your Dreams’
# 9                              UNCHANGING PT. 1
#
#                         Single_Album_Id
# 0  spotify:album:63fxv7o113Zji3oLeXgswm
# 1  spotify:album:7vqIRL00YfTtuO0sSAK3Uv
# 2  spotify:album:6pN2wvuzGHURmVNXbpRaei
# 3  spotify:album:3j2XirA7CqIqkwuQfO7wkR
# 4  spotify:album:4jBlaJL3oauZCX9VeseBJC
# 5  spotify:album:1Qwyg4hhC6gv8x42kq9Qru
# 6  spotify:album:08u61FSaRTXKe6CD7RePvp
# 7  spotify:album:1F4ew4S5UvxCTg28U2J1cR
# 8  spotify:album:2txBzMBsQDnw0kT6rFpQRB
# 9  spotify:album:5TrZNDuG4byRTlcMsX6OaS

# %%
list_of_single_track_df = []

for ind in singles_input_data.index:
    single_album_id = singles_input_data["Single_Album_Id"][ind]
    tracks = sp.album_tracks(album_id = single_album_id)

    try:
        for track in tracks['items']:
            # Retrieve each track's Spotify qualities
            track_name = track['name']
            track_uri = track['uri']
            track_features = sp.audio_features(track_uri)
            track_features_df = pd.DataFrame(track_features)
            track_features_df['Track_Title'] = track_name

            # Combine track and artist information with the features dataframe
            temp_df = pd.concat([singles_input_data.loc[ind:ind], 
                                track_features_df.set_index(singles_input_data.loc[ind:ind].index)], axis = 1)
            list_of_single_track_df.append(temp_df)

    except:
        print("Ran into an error - rerun please!")
        print(single_album_id)

# %%
temp_df = pd.concat(list_of_single_track_df, ignore_index=True)

# %%
temp_df.head(10)
# Out:
#    Unnamed: 0     Artist               Artist_Id          Single_Album_Name  \
# 0           0  SECHSKIES  6uRyNreOHUvWPNGnKfIo27            DON'T LOOK BACK
# 1           1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27                ALL FOR YOU
# 2           1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27                ALL FOR YOU
# 3           1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27                ALL FOR YOU
# 4           1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27                ALL FOR YOU
# 5           1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27                ALL FOR YOU
# 6           2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27                THREE WORDS
# 7           3     S.E.S.  61HUG80Xma4rnXsqfZkzeM  Love (story) - SM STATION
# 8           3     S.E.S.  61HUG80Xma4rnXsqfZkzeM  Love (story) - SM STATION
# 9           4     S.E.S.  61HUG80Xma4rnXsqfZkzeM                    Remixed
#
#                         Single_Album_Id  danceability  energy   key  loudness  \
# 0  spotify:album:63fxv7o113Zji3oLeXgswm         0.535   0.484   0.0    -8.209
# 1  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.622   0.756   4.0    -4.838
# 2  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.676   0.593  11.0    -5.368
# 3  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.793   0.799   7.0    -3.051
# 4  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.702   0.702   5.0    -4.210
# 5  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.751   0.735   0.0    -3.240
# 6  spotify:album:6pN2wvuzGHURmVNXbpRaei         0.650   0.616   0.0    -4.690
# 7  spotify:album:3j2XirA7CqIqkwuQfO7wkR         0.714   0.931   5.0    -2.093
# 8  spotify:album:3j2XirA7CqIqkwuQfO7wkR         0.756   0.896   7.0    -4.253
# 9  spotify:album:4jBlaJL3oauZCX9VeseBJC         0.751   0.923   0.0    -4.242
#
#    mode  ...    tempo            type                      id  \
# 0   1.0  ...  124.038  audio_features  3szqGZtiiS8hmIPcT9qBgh
# 1   0.0  ...  167.902  audio_features  4jB0ikdBeXiIIP97TPXIPt
# 2   1.0  ...  140.011  audio_features  5d0AZT2CWAH4mApoiXlTDa
# 3   0.0  ...  122.989  audio_features  2FHTNle5MybRe4k0GfjHFq
# 4   0.0  ...  130.045  audio_features  0pO0z7133jfdG6MkGA5Mym
# 5   0.0  ...  125.950  audio_features  7yTryQD1n1PGjrqKTxh4na
# 6   1.0  ...  147.991  audio_features  3xxqDGYqGNTIi5H8KJHDtC
# 7   1.0  ...  103.010  audio_features  7jdRhISt05YmJAKD0eGEeX
# 8   1.0  ...  103.009  audio_features  0jT6xrrvWpeVgnk3d8X1lr
# 9   1.0  ...  113.004  audio_features  6p9nbwXxgbLnsUOM5XCcGV
#
#                                     uri  \
# 0  spotify:track:3szqGZtiiS8hmIPcT9qBgh
# 1  spotify:track:4jB0ikdBeXiIIP97TPXIPt
# 2  spotify:track:5d0AZT2CWAH4mApoiXlTDa
# 3  spotify:track:2FHTNle5MybRe4k0GfjHFq
# 4  spotify:track:0pO0z7133jfdG6MkGA5Mym
# 5  spotify:track:7yTryQD1n1PGjrqKTxh4na
# 6  spotify:track:3xxqDGYqGNTIi5H8KJHDtC
# 7  spotify:track:7jdRhISt05YmJAKD0eGEeX
# 8  spotify:track:0jT6xrrvWpeVgnk3d8X1lr
# 9  spotify:track:6p9nbwXxgbLnsUOM5XCcGV
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3szqGZtiiS8h...
# 1  https://api.spotify.com/v1/tracks/4jB0ikdBeXiI...
# 2  https://api.spotify.com/v1/tracks/5d0AZT2CWAH4...
# 3  https://api.spotify.com/v1/tracks/2FHTNle5MybR...
# 4  https://api.spotify.com/v1/tracks/0pO0z7133jfd...
# 5  https://api.spotify.com/v1/tracks/7yTryQD1n1PG...
# 6  https://api.spotify.com/v1/tracks/3xxqDGYqGNTI...
# 7  https://api.spotify.com/v1/tracks/7jdRhISt05Ym...
# 8  https://api.spotify.com/v1/tracks/0jT6xrrvWpeV...
# 9  https://api.spotify.com/v1/tracks/6p9nbwXxgbLn...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3szq...    249263.0
# 1  https://api.spotify.com/v1/audio-analysis/4jB0...    242977.0
# 2  https://api.spotify.com/v1/audio-analysis/5d0A...    243714.0
# 3  https://api.spotify.com/v1/audio-analysis/2FHT...    221587.0
# 4  https://api.spotify.com/v1/audio-analysis/0pO0...    246303.0
# 5  https://api.spotify.com/v1/audio-analysis/7yTr...    221595.0
# 6  https://api.spotify.com/v1/audio-analysis/3xxq...    243243.0
# 7  https://api.spotify.com/v1/audio-analysis/7jdR...    239093.0
# 8  https://api.spotify.com/v1/audio-analysis/0jT6...    235579.0
# 9  https://api.spotify.com/v1/audio-analysis/6p9n...    217133.0
#
#   time_signature                  Track_Title    0
# 0            4.0              DON’T LOOK BACK  NaN
# 1            4.0                  ALL FOR YOU  NaN
# 2            4.0                        DREAM  NaN
# 3            4.0                  MEANINGLESS  NaN
# 4            4.0                ROUND & ROUND  NaN
# 5            4.0           WALKING IN THE SKY  NaN
# 6            4.0                  THREE WORDS  NaN
# 7            4.0                 Love [story]  NaN
# 8            4.0  Love [story] - Instrumental  NaN
# 9            4.0       달리기 - J-Bait Disco Mix  NaN
#
# [10 rows x 25 columns]

# %%
temp_df.to_csv("v1_single_album_to_song.csv")

# %% [markdown]
# ### Locating and Attaching "Appears On"

# %%
appears_on_input_data = pd.read_csv("artist_id_appears_on_id.csv")

# %%
appears_on_input_data.head(10)
# Out:
#    Unnamed: 0     Artist               Artist_Id  \
# 0           0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 1           1     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 2           2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 3           3     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 4           4     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 5           5     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 6           6     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 7           7     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 8           8    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 9           9    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
#
#                               Appears_On_Name  \
# 0               Winter Vacation in SMTOWN.com
# 1                     Christmas in SMTOWN.com
# 2     90's trendy K-pop music Best 20 Vol. 15
# 3              Superhero (My Knight) Remix EP
# 4          2002 SUMMER VACATION in SMTOWN.COM
# 5  Winter Vacation in SMTOWN.com - Angel Eyes
# 6               Winter Vacation in SMTOWN.com
# 7                     Christmas in SMTOWN.com
# 8                                        韓劇情緣
# 9               All About Eve (MBC DRAMA) OST
#
#                           Appears_On_Id
# 0  spotify:album:5aBuzpJ2UNoPwQhee47UQk
# 1  spotify:album:7ccOMxO0n9DjSfLBHhWMDT
# 2  spotify:album:2lW9DhcA1StfL54mw5pgC2
# 3  spotify:album:5v6Jrf7O7k99sPkMTU2Noo
# 4  spotify:album:59KnIxsURaQ1wabZZpyf67
# 5  spotify:album:3nHNulZ1pybkNcM5NeErQA
# 6  spotify:album:5aBuzpJ2UNoPwQhee47UQk
# 7  spotify:album:7ccOMxO0n9DjSfLBHhWMDT
# 8  spotify:album:2SgMnH1w8G47RWCAt18wwY
# 9  spotify:album:7LDnsb1ATqmSM3NYqefvfL

# %%
# list_of_appears_on_track_df = []

# for ind in appears_on_input_data.index:
#     appears_on_album_id = appears_on_input_data["Appears_On_Id"][ind]
#     tracks = sp.album_tracks(album_id = appears_on_album_id)
    
#     try:
#         for track in tracks['items']:
#             # Retrieve each track's Spotify qualities
#             track_name = track['name']
#             track_uri = track['uri']
#             track_features = sp.audio_features(track_uri)
#             track_features_df = pd.DataFrame(track_features)
#             track_features_df['Track_Title'] = track_name

#             # Combine track and artist information with the features dataframe
#             temp_df = pd.concat([appears_on_input_data.loc[ind:ind], 
#                                 track_features_df.set_index(appears_on_input_data.loc[ind:ind].index)], axis = 1)
#             list_of_appears_on_track_df.append(temp_df)

#     except:
#         print("Ran into an error - rerun please!")
#         print(appears_on_album_id)

# %% [markdown]
# ### Locating and Attaching "Compilation"

# %%
artist_compilation_data = pd.read_csv("artist_id_compilation_id.csv", index_col = 0)

# %%
artist_compilation_data.head(10)
# Out:
#        Artist               Artist_Id  \
# 0     Click-B  2kOGSFThgEzPEjL4fFB25w
# 1         BoA  4muJrGMndyYWqZtfk8OWy4
# 2     BIGBANG  4Kxlr1PRlDKEB0ekOCyHgX
# 3         2PM  5iRPbkcPmqAFFwDUj6ywVS
# 4         BTS  3Nrfpe0tUJi4K4DXYWgMUX
# 5  Stray Kids  2dIgFjalVxs4ThymZ67YCE
# 6     4Minute  6cdC1cwqh3eJAXaxXJt2jv
# 7    G-Dragon  30b9WulBM8sFuBo17nNq9c
# 8     TAEYANG  6udveWUgX4vu75FF0DTrXV
# 9        BIBI  6UbmqUEgjLA6jAcXwbM1Z9
#
#                                Compilation_Name  \
# 0                           The Best Of Click-B
# 1                                  BEST OF SOUL
# 2                 THE BEST OF BIGBANG 2006-2014
# 3            THE BEST OF 2PM in Japan 2011-2016
# 4                                 BTS, THE BEST
# 5                                       SKZ2020
# 6                               Best of 4Minute
# 7  COUP D'ETAT [+ ONE OF A KIND & HEARTBREAKER]
# 8                          RISE [+ SOLAR & HOT]
# 9                                       Gringas
#
#                          Compilation_Id
# 0  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO
# 1  spotify:album:0gxS6h33HGI5jEAgcMsTWA
# 2  spotify:album:1JwbdXLKJVffgSW95WcTUp
# 3  spotify:album:5rEgHD2JSK9RRxyKtXsImD
# 4  spotify:album:6bN241dPMC54Ac6zV1B8hl
# 5  spotify:album:4hk05fFLNquJc8w5htXZDi
# 6  spotify:album:502uBQOdyp6A3En53ZJFCo
# 7  spotify:album:1mVPbaMZGsPh5gzhvO6BBX
# 8  spotify:album:2Z80u1PO03Jk4eUccBUR90
# 9  spotify:album:37IFkjRyzSbBWubkkHD6RL

# %%
list_of_compilations_track_df = []

for ind in artist_compilation_data.index:
    compilation_id = artist_compilation_data["Compilation_Id"][ind]
    tracks = sp.album_tracks(album_id = compilation_id)
    
    try:
        for track in tracks['items']:
            # Retrieve each track's Spotify qualities
            track_name = track['name']
            track_uri = track['uri']
            track_features = sp.audio_features(track_uri)
            track_features_df = pd.DataFrame(track_features)
            track_features_df['Track_Title'] = track_name

            # Combine track and artist information with the features dataframe
            temp_df = pd.concat([artist_compilation_data.loc[ind:ind], 
                                track_features_df.set_index(artist_compilation_data.loc[ind:ind].index)], axis = 1)
            list_of_compilations_track_df.append(temp_df)

    except:
        print("Ran into an error - rerun please!")
        print(compilation_id)

# %%
temp_df = pd.concat(list_of_compilations_track_df, ignore_index=True)

# %%
temp_df.head(10)
# Out:
#     Artist               Artist_Id     Compilation_Name  \
# 0  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 1  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 2  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 3  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 4  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 5  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 6  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 7  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 8  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 9  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
#
#                          Compilation_Id  danceability  energy  key  loudness  \
# 0  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.765   0.877   10    -4.082
# 1  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.321   0.887    7    -4.371
# 2  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.570   0.956    6    -5.014
# 3  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.676   0.404    9    -7.232
# 4  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.548   0.912    9    -4.659
# 5  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.604   0.955    2    -4.646
# 6  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.815   0.845    6    -3.799
# 7  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.612   0.962    8    -4.688
# 8  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.646   0.979    4    -3.510
# 9  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.559   0.907    7    -5.192
#
#    mode  speechiness  ...  valence    tempo            type  \
# 0     0       0.0614  ...    0.933  102.038  audio_features
# 1     1       0.2370  ...    0.275   78.301  audio_features
# 2     1       0.0640  ...    0.834  144.994  audio_features
# 3     0       0.0909  ...    0.673   68.011  audio_features
# 4     1       0.1990  ...    0.311   98.039  audio_features
# 5     1       0.0484  ...    0.565  116.020  audio_features
# 6     0       0.1830  ...    0.793   96.986  audio_features
# 7     1       0.0544  ...    0.853  102.003  audio_features
# 8     0       0.0903  ...    0.684  102.001  audio_features
# 9     0       0.0389  ...    0.571  142.949  audio_features
#
#                        id                                   uri  \
# 0  5ylUgQPsprPXqbj40qbY76  spotify:track:5ylUgQPsprPXqbj40qbY76
# 1  7GfcHqyVb9VdHBGHhTcYuU  spotify:track:7GfcHqyVb9VdHBGHhTcYuU
# 2  5WwkjpQCnMvLAGYnXwCgWb  spotify:track:5WwkjpQCnMvLAGYnXwCgWb
# 3  453ZYLlY6PSIuvqMrI9Bn6  spotify:track:453ZYLlY6PSIuvqMrI9Bn6
# 4  4WrcbHIcp7ND1BwPCb5ota  spotify:track:4WrcbHIcp7ND1BwPCb5ota
# 5  7GM1Lo9s6kyI1rn2vPHp94  spotify:track:7GM1Lo9s6kyI1rn2vPHp94
# 6  6WS11nF6DZl9LeMDTmJWpI  spotify:track:6WS11nF6DZl9LeMDTmJWpI
# 7  0fTqVwWqGbpFUe3bgJ9mHl  spotify:track:0fTqVwWqGbpFUe3bgJ9mHl
# 8  1eR8EcfbPAYeHqvMsyEh2z  spotify:track:1eR8EcfbPAYeHqvMsyEh2z
# 9  1Qy4SrFeh1kaL2mtVBKbfB  spotify:track:1Qy4SrFeh1kaL2mtVBKbfB
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5ylUgQPsprPX...
# 1  https://api.spotify.com/v1/tracks/7GfcHqyVb9Vd...
# 2  https://api.spotify.com/v1/tracks/5WwkjpQCnMvL...
# 3  https://api.spotify.com/v1/tracks/453ZYLlY6PSI...
# 4  https://api.spotify.com/v1/tracks/4WrcbHIcp7ND...
# 5  https://api.spotify.com/v1/tracks/7GM1Lo9s6kyI...
# 6  https://api.spotify.com/v1/tracks/6WS11nF6DZl9...
# 7  https://api.spotify.com/v1/tracks/0fTqVwWqGbpF...
# 8  https://api.spotify.com/v1/tracks/1eR8EcfbPAYe...
# 9  https://api.spotify.com/v1/tracks/1Qy4SrFeh1ka...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5ylU...      204760
# 1  https://api.spotify.com/v1/audio-analysis/7Gfc...      191107
# 2  https://api.spotify.com/v1/audio-analysis/5Wwk...      214427
# 3  https://api.spotify.com/v1/audio-analysis/453Z...      247907
# 4  https://api.spotify.com/v1/audio-analysis/4Wrc...      250827
# 5  https://api.spotify.com/v1/audio-analysis/7GM1...      258133
# 6  https://api.spotify.com/v1/audio-analysis/6WS1...      209267
# 7  https://api.spotify.com/v1/audio-analysis/0fTq...      222240
# 8  https://api.spotify.com/v1/audio-analysis/1eR8...      265867
# 9  https://api.spotify.com/v1/audio-analysis/1Qy4...      234187
#
#   time_signature  Track_Title
# 0              4          스캔들
# 1              4        보라빛향기
# 2              4    Never Say
# 3              4      단한번만...
# 4              4     Break It
# 5              4          환영문
# 6              4       Cowboy
# 7              4  Love Letter
# 8              4         백전무패
# 9              4          하늘아
#
# [10 rows x 23 columns]

# %%
temp_df.to_csv("v1_artist_to_compilation.csv")

# %% [markdown]
# ## Cleaning Scraped Data

# %% [markdown]
# ### Fixing the Album and Tracks Dataframe

# %%
album_track_data = pd.read_csv("v1_album_to_song.csv", index_col = 0)
album_track_data.head(5)
# Out:
#    Artist               Artist_Id                 Album_Name  \
# 0  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 1  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 2  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 3  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 4  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
#
#                                Album_Id  danceability  energy   key  loudness  \
# 0  spotify:album:697cPaD568S5Zt4bgo4cQf         0.209   0.963   6.0   -12.900
# 1  spotify:album:697cPaD568S5Zt4bgo4cQf         0.397   0.901   4.0    -6.970
# 2  spotify:album:697cPaD568S5Zt4bgo4cQf         0.542   0.913   1.0    -7.763
# 3  spotify:album:697cPaD568S5Zt4bgo4cQf         0.436   0.666  10.0   -14.143
# 4  spotify:album:697cPaD568S5Zt4bgo4cQf         0.366   0.778   7.0    -9.239
#
#    mode  speechiness  ...    tempo            type                      id  \
# 0   0.0       0.1330  ...  131.864  audio_features  6KOn7RweqUBSZWoKKkHFRb
# 1   1.0       0.2850  ...  171.944  audio_features  1khANf67sdS8kUkjmF218J
# 2   1.0       0.2410  ...   97.051  audio_features  4XkT2bHdbHMPukCpj7mXPJ
# 3   0.0       0.6320  ...  107.013  audio_features  65a4TY00ChiawzHVH4xcDO
# 4   0.0       0.0714  ...   99.995  audio_features  3vYZaL9lMZ1uKURbcEq4Jz
#
#                                     uri  \
# 0  spotify:track:6KOn7RweqUBSZWoKKkHFRb
# 1  spotify:track:1khANf67sdS8kUkjmF218J
# 2  spotify:track:4XkT2bHdbHMPukCpj7mXPJ
# 3  spotify:track:65a4TY00ChiawzHVH4xcDO
# 4  spotify:track:3vYZaL9lMZ1uKURbcEq4Jz
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/6KOn7RweqUBS...
# 1  https://api.spotify.com/v1/tracks/1khANf67sdS8...
# 2  https://api.spotify.com/v1/tracks/4XkT2bHdbHMP...
# 3  https://api.spotify.com/v1/tracks/65a4TY00Chia...
# 4  https://api.spotify.com/v1/tracks/3vYZaL9lMZ1u...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/6KOn...     90333.0
# 1  https://api.spotify.com/v1/audio-analysis/1khA...    278333.0
# 2  https://api.spotify.com/v1/audio-analysis/4XkT...    320533.0
# 3  https://api.spotify.com/v1/audio-analysis/65a4...    284427.0
# 4  https://api.spotify.com/v1/audio-analysis/3vYZ...    278667.0
#
#   time_signature                                        Track_Title   0
# 0            4.0                                     Opening - Live NaN
# 1            4.0                                      I yah! - Live NaN
# 2            4.0           Git It Up! / 전사의 후예 / You Got Gun - Live NaN
# 3            5.0                                Opening Ment - Live NaN
# 4            4.0  It's Been Raining Since You Left Me / Delight ... NaN
#
# [5 rows x 24 columns]

# %%
# Drop unneeded columnms
# print(album_track_data.columns)
album_track_data.drop(['uri','track_href','analysis_url','type','0'], axis=1, inplace=True)

# Drop the 'spotify:album:' part of the 'Album_Id' columns
album_track_data['Album_Id'] = album_track_data['Album_Id'].str[14:]

# %%
album_track_data.head(5)
# Out:
#    Artist               Artist_Id                 Album_Name  \
# 0  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 1  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 2  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 3  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 4  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
#
#                  Album_Id  danceability  energy   key  loudness  mode  \
# 0  697cPaD568S5Zt4bgo4cQf         0.209   0.963   6.0   -12.900   0.0
# 1  697cPaD568S5Zt4bgo4cQf         0.397   0.901   4.0    -6.970   1.0
# 2  697cPaD568S5Zt4bgo4cQf         0.542   0.913   1.0    -7.763   1.0
# 3  697cPaD568S5Zt4bgo4cQf         0.436   0.666  10.0   -14.143   0.0
# 4  697cPaD568S5Zt4bgo4cQf         0.366   0.778   7.0    -9.239   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1330       0.00009          0.913000     0.322   0.0829  131.864
# 1       0.2850       0.06650          0.000000     0.888   0.2580  171.944
# 2       0.2410       0.10800          0.000315     0.890   0.3770   97.051
# 3       0.6320       0.92500          0.000267     0.855   0.0800  107.013
# 4       0.0714       0.16400          0.000214     0.891   0.4040   99.995
#
#                        id  duration_ms  time_signature  \
# 0  6KOn7RweqUBSZWoKKkHFRb      90333.0             4.0
# 1  1khANf67sdS8kUkjmF218J     278333.0             4.0
# 2  4XkT2bHdbHMPukCpj7mXPJ     320533.0             4.0
# 3  65a4TY00ChiawzHVH4xcDO     284427.0             5.0
# 4  3vYZaL9lMZ1uKURbcEq4Jz     278667.0             4.0
#
#                                          Track_Title
# 0                                     Opening - Live
# 1                                      I yah! - Live
# 2           Git It Up! / 전사의 후예 / You Got Gun - Live
# 3                                Opening Ment - Live
# 4  It's Been Raining Since You Left Me / Delight ...

# %%
# Bring the 'Track Title' column to the right of 'Album_Id'
column_to_move = album_track_data.pop("Track_Title")
album_track_data.insert(4, "Track_Title", column_to_move)
column_to_move = album_track_data.pop("id")
album_track_data.insert(5, "Track_Id", column_to_move)
album_track_data.head()
# Out:
#    Artist               Artist_Id                 Album_Name  \
# 0  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 1  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 2  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 3  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
# 4  H.O.T.  5JrfgZAgqAMywJpLpJM0eS  FOREVER 2001 LIVE CONCERT
#
#                  Album_Id                                        Track_Title  \
# 0  697cPaD568S5Zt4bgo4cQf                                     Opening - Live
# 1  697cPaD568S5Zt4bgo4cQf                                      I yah! - Live
# 2  697cPaD568S5Zt4bgo4cQf           Git It Up! / 전사의 후예 / You Got Gun - Live
# 3  697cPaD568S5Zt4bgo4cQf                                Opening Ment - Live
# 4  697cPaD568S5Zt4bgo4cQf  It's Been Raining Since You Left Me / Delight ...
#
#                  Track_Id  danceability  energy   key  loudness  mode  \
# 0  6KOn7RweqUBSZWoKKkHFRb         0.209   0.963   6.0   -12.900   0.0
# 1  1khANf67sdS8kUkjmF218J         0.397   0.901   4.0    -6.970   1.0
# 2  4XkT2bHdbHMPukCpj7mXPJ         0.542   0.913   1.0    -7.763   1.0
# 3  65a4TY00ChiawzHVH4xcDO         0.436   0.666  10.0   -14.143   0.0
# 4  3vYZaL9lMZ1uKURbcEq4Jz         0.366   0.778   7.0    -9.239   0.0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1330       0.00009          0.913000     0.322   0.0829  131.864
# 1       0.2850       0.06650          0.000000     0.888   0.2580  171.944
# 2       0.2410       0.10800          0.000315     0.890   0.3770   97.051
# 3       0.6320       0.92500          0.000267     0.855   0.0800  107.013
# 4       0.0714       0.16400          0.000214     0.891   0.4040   99.995
#
#    duration_ms  time_signature
# 0      90333.0             4.0
# 1     278333.0             4.0
# 2     320533.0             4.0
# 3     284427.0             5.0
# 4     278667.0             4.0

# %%
album_track_data.to_csv("cleaned_album_to_track_df.csv")

# %% [markdown]
# ### Fixing the 'Appears On' Dataframe

# %%
appears_on_data = pd.read_csv("artist_appears_on.csv", index_col=0)

# %%
appears_on_data.head()
# Out:
#       Artist               Artist_Id                          Appears_On_Name  \
# 0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS            Winter Vacation in SMTOWN.com
# 1     H.O.T.  5JrfgZAgqAMywJpLpJM0eS                  Christmas in SMTOWN.com
# 2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27  90's trendy K-pop music Best 20 Vol. 15
# 3     S.E.S.  61HUG80Xma4rnXsqfZkzeM           Superhero (My Knight) Remix EP
# 4     S.E.S.  61HUG80Xma4rnXsqfZkzeM       2002 SUMMER VACATION in SMTOWN.COM
#
#             Appears_On_Id
# 0  5aBuzpJ2UNoPwQhee47UQk
# 1  7ccOMxO0n9DjSfLBHhWMDT
# 2  2lW9DhcA1StfL54mw5pgC2
# 3  5v6Jrf7O7k99sPkMTU2Noo
# 4  59KnIxsURaQ1wabZZpyf67

# %%
# Drop the 'spotify:album:' part of the 'Appears_On_Id' columns
appears_on_data['Appears_On_Id'] = appears_on_data['Appears_On_Id'].str[14:]
appears_on_data.head(3)
# Out:
#       Artist               Artist_Id                          Appears_On_Name  \
# 0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS            Winter Vacation in SMTOWN.com
# 1     H.O.T.  5JrfgZAgqAMywJpLpJM0eS                  Christmas in SMTOWN.com
# 2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27  90's trendy K-pop music Best 20 Vol. 15
#
#   Appears_On_Id
# 0      hee47UQk
# 1      LBHhWMDT
# 2      4mw5pgC2

# %%
appears_on_data.to_csv("artist_appears_on_df.csv")

# %% [markdown]
# ### Fixing the Singles and 'Singles Album' Dataframe

# %%
single_album_track_data = pd.read_csv("v1_single_album_to_song.csv", index_col = 0)
single_album_track_data.head(5)
# Out:
#    Unnamed: 0.1     Artist               Artist_Id Single_Album_Name  \
# 0             0  SECHSKIES  6uRyNreOHUvWPNGnKfIo27   DON'T LOOK BACK
# 1             1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
# 2             1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
# 3             1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
# 4             1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
#
#                         Single_Album_Id  danceability  energy   key  loudness  \
# 0  spotify:album:63fxv7o113Zji3oLeXgswm         0.535   0.484   0.0    -8.209
# 1  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.622   0.756   4.0    -4.838
# 2  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.676   0.593  11.0    -5.368
# 3  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.793   0.799   7.0    -3.051
# 4  spotify:album:7vqIRL00YfTtuO0sSAK3Uv         0.702   0.702   5.0    -4.210
#
#    mode  ...    tempo            type                      id  \
# 0   1.0  ...  124.038  audio_features  3szqGZtiiS8hmIPcT9qBgh
# 1   0.0  ...  167.902  audio_features  4jB0ikdBeXiIIP97TPXIPt
# 2   1.0  ...  140.011  audio_features  5d0AZT2CWAH4mApoiXlTDa
# 3   0.0  ...  122.989  audio_features  2FHTNle5MybRe4k0GfjHFq
# 4   0.0  ...  130.045  audio_features  0pO0z7133jfdG6MkGA5Mym
#
#                                     uri  \
# 0  spotify:track:3szqGZtiiS8hmIPcT9qBgh
# 1  spotify:track:4jB0ikdBeXiIIP97TPXIPt
# 2  spotify:track:5d0AZT2CWAH4mApoiXlTDa
# 3  spotify:track:2FHTNle5MybRe4k0GfjHFq
# 4  spotify:track:0pO0z7133jfdG6MkGA5Mym
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3szqGZtiiS8h...
# 1  https://api.spotify.com/v1/tracks/4jB0ikdBeXiI...
# 2  https://api.spotify.com/v1/tracks/5d0AZT2CWAH4...
# 3  https://api.spotify.com/v1/tracks/2FHTNle5MybR...
# 4  https://api.spotify.com/v1/tracks/0pO0z7133jfd...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3szq...    249263.0
# 1  https://api.spotify.com/v1/audio-analysis/4jB0...    242977.0
# 2  https://api.spotify.com/v1/audio-analysis/5d0A...    243714.0
# 3  https://api.spotify.com/v1/audio-analysis/2FHT...    221587.0
# 4  https://api.spotify.com/v1/audio-analysis/0pO0...    246303.0
#
#   time_signature      Track_Title   0
# 0            4.0  DON’T LOOK BACK NaN
# 1            4.0      ALL FOR YOU NaN
# 2            4.0            DREAM NaN
# 3            4.0      MEANINGLESS NaN
# 4            4.0    ROUND & ROUND NaN
#
# [5 rows x 25 columns]

# %%
single_album_track_data.columns
# Out:
# Index(['Unnamed: 0.1', 'Artist', 'Artist_Id', 'Single_Album_Name',
#        'Single_Album_Id', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'Track_Title', '0'],
#       dtype='object')

# %%
# Drop unneeded columnms
single_album_track_data.drop(['Unnamed: 0.1','uri','track_href','analysis_url','type','0'], axis=1, inplace=True)

# Drop the 'spotify:album:' part of the 'Single_Album_Id' columns
single_album_track_data['Single_Album_Id'] = single_album_track_data['Single_Album_Id'].str[14:]

# Bring the 'Track Title' column to the right of 'Album_Id', while moving the 'id' column and renaming it as well
column_to_move = single_album_track_data.pop("Track_Title")
single_album_track_data.insert(4, "Track_Title", column_to_move)

column_to_move = single_album_track_data.pop("id")
single_album_track_data.insert(5, "Track_Id", column_to_move)

single_album_track_data.head()
# Out:
#       Artist               Artist_Id Single_Album_Name  \
# 0  SECHSKIES  6uRyNreOHUvWPNGnKfIo27   DON'T LOOK BACK
# 1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
# 2  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
# 3  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
# 4  SECHSKIES  6uRyNreOHUvWPNGnKfIo27       ALL FOR YOU
#
#           Single_Album_Id      Track_Title                Track_Id  \
# 0  63fxv7o113Zji3oLeXgswm  DON’T LOOK BACK  3szqGZtiiS8hmIPcT9qBgh
# 1  7vqIRL00YfTtuO0sSAK3Uv      ALL FOR YOU  4jB0ikdBeXiIIP97TPXIPt
# 2  7vqIRL00YfTtuO0sSAK3Uv            DREAM  5d0AZT2CWAH4mApoiXlTDa
# 3  7vqIRL00YfTtuO0sSAK3Uv      MEANINGLESS  2FHTNle5MybRe4k0GfjHFq
# 4  7vqIRL00YfTtuO0sSAK3Uv    ROUND & ROUND  0pO0z7133jfdG6MkGA5Mym
#
#    danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0         0.535   0.484   0.0    -8.209   1.0       0.0301        0.6780
# 1         0.622   0.756   4.0    -4.838   0.0       0.0473        0.0705
# 2         0.676   0.593  11.0    -5.368   1.0       0.0346        0.3030
# 3         0.793   0.799   7.0    -3.051   0.0       0.0318        0.1890
# 4         0.702   0.702   5.0    -4.210   0.0       0.0290        0.1280
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0          0.000002     0.108    0.233  124.038     249263.0             4.0
# 1          0.000000     0.108    0.718  167.902     242977.0             4.0
# 2          0.000000     0.120    0.314  140.011     243714.0             4.0
# 3          0.000000     0.112    0.777  122.989     221587.0             4.0
# 4          0.000000     0.121    0.570  130.045     246303.0             4.0

# %%
single_album_track_data.to_csv("cleaned_single_album_track_data.csv")

# %% [markdown]
# ### Fixing the Compilation Dataframe

# %%
compilation_track_data = pd.read_csv("v1_artist_to_compilation.csv", index_col = 0)
compilation_track_data.head()
# Out:
#     Artist               Artist_Id     Compilation_Name  \
# 0  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 1  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 2  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 3  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 4  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
#
#                          Compilation_Id  danceability  energy  key  loudness  \
# 0  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.765   0.877   10    -4.082
# 1  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.321   0.887    7    -4.371
# 2  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.570   0.956    6    -5.014
# 3  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.676   0.404    9    -7.232
# 4  spotify:album:7v8ud1pc0Y9xvPGFtVJYbO         0.548   0.912    9    -4.659
#
#    mode  speechiness  ...  valence    tempo            type  \
# 0     0       0.0614  ...    0.933  102.038  audio_features
# 1     1       0.2370  ...    0.275   78.301  audio_features
# 2     1       0.0640  ...    0.834  144.994  audio_features
# 3     0       0.0909  ...    0.673   68.011  audio_features
# 4     1       0.1990  ...    0.311   98.039  audio_features
#
#                        id                                   uri  \
# 0  5ylUgQPsprPXqbj40qbY76  spotify:track:5ylUgQPsprPXqbj40qbY76
# 1  7GfcHqyVb9VdHBGHhTcYuU  spotify:track:7GfcHqyVb9VdHBGHhTcYuU
# 2  5WwkjpQCnMvLAGYnXwCgWb  spotify:track:5WwkjpQCnMvLAGYnXwCgWb
# 3  453ZYLlY6PSIuvqMrI9Bn6  spotify:track:453ZYLlY6PSIuvqMrI9Bn6
# 4  4WrcbHIcp7ND1BwPCb5ota  spotify:track:4WrcbHIcp7ND1BwPCb5ota
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5ylUgQPsprPX...
# 1  https://api.spotify.com/v1/tracks/7GfcHqyVb9Vd...
# 2  https://api.spotify.com/v1/tracks/5WwkjpQCnMvL...
# 3  https://api.spotify.com/v1/tracks/453ZYLlY6PSI...
# 4  https://api.spotify.com/v1/tracks/4WrcbHIcp7ND...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5ylU...      204760
# 1  https://api.spotify.com/v1/audio-analysis/7Gfc...      191107
# 2  https://api.spotify.com/v1/audio-analysis/5Wwk...      214427
# 3  https://api.spotify.com/v1/audio-analysis/453Z...      247907
# 4  https://api.spotify.com/v1/audio-analysis/4Wrc...      250827
#
#   time_signature Track_Title
# 0              4         스캔들
# 1              4       보라빛향기
# 2              4   Never Say
# 3              4     단한번만...
# 4              4    Break It
#
# [5 rows x 23 columns]

# %%
# Drop unneeded columnms
compilation_track_data.drop(['uri','track_href','analysis_url','type'], axis=1, inplace=True)

# Drop the 'spotify:album:' part of the 'Compilation_Id' columns
compilation_track_data['Compilation_Id'] = compilation_track_data['Compilation_Id'].str[14:]

# Bring the 'Track Title' column to the right of 'Album_Id', while moving the 'id' column and renaming it as well
column_to_move = compilation_track_data.pop("Track_Title")
compilation_track_data.insert(4, "Track_Title", column_to_move)

column_to_move = compilation_track_data.pop("id")
compilation_track_data.insert(5, "Track_Id", column_to_move)

compilation_track_data.head()
# Out:
#     Artist               Artist_Id     Compilation_Name  \
# 0  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 1  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 2  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 3  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
# 4  Click-B  2kOGSFThgEzPEjL4fFB25w  The Best Of Click-B
#
#            Compilation_Id Track_Title                Track_Id  danceability  \
# 0  7v8ud1pc0Y9xvPGFtVJYbO         스캔들  5ylUgQPsprPXqbj40qbY76         0.765
# 1  7v8ud1pc0Y9xvPGFtVJYbO       보라빛향기  7GfcHqyVb9VdHBGHhTcYuU         0.321
# 2  7v8ud1pc0Y9xvPGFtVJYbO   Never Say  5WwkjpQCnMvLAGYnXwCgWb         0.570
# 3  7v8ud1pc0Y9xvPGFtVJYbO     단한번만...  453ZYLlY6PSIuvqMrI9Bn6         0.676
# 4  7v8ud1pc0Y9xvPGFtVJYbO    Break It  4WrcbHIcp7ND1BwPCb5ota         0.548
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.877   10    -4.082     0       0.0614       0.01850          0.000018
# 1   0.887    7    -4.371     1       0.2370       0.00455          0.000000
# 2   0.956    6    -5.014     1       0.0640       0.00292          0.000000
# 3   0.404    9    -7.232     0       0.0909       0.17100          0.000391
# 4   0.912    9    -4.659     1       0.1990       0.00195          0.000000
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0    0.0982    0.933  102.038       204760               4
# 1    0.2880    0.275   78.301       191107               4
# 2    0.2820    0.834  144.994       214427               4
# 3    0.1330    0.673   68.011       247907               4
# 4    0.1540    0.311   98.039       250827               4

# %%
compilation_track_data.to_csv("cleaned_compilation_track.csv")

# %%
artist_album_input = pd.read_csv("275_kArtists.csv")

# %%
artist_album_input.head()
# Out:
#       Artist              Spotify_Id
# 0     H.O.T.  5JrfgZAgqAMywJpLpJM0eS
# 1  SECHSKIES  6uRyNreOHUvWPNGnKfIo27
# 2     S.E.S.  61HUG80Xma4rnXsqfZkzeM
# 3    Fin.K.L  2aRLyjYp7WPr4EkjkI1gvS
# 4    Shinhwa  0jVvkFPa6YbFXQ3Qmhita0

# %%
len(artist_album_input["Artist"].unique())
# Out:
# 274

# %%
temp_list = artist_album_input["Spotify_Id"]

# %%
for i in range(0,len(temp_list)):
    for j in range(i+1,len(temp_list)):
        if temp_list[i] == temp_list[j]:
            print("found")
            print(temp_list[i])
            print(temp_list[j])
# Out:
# found
# 7cVZApDoQZpS447nHTsNqu
# 7cVZApDoQZpS447nHTsNqu
